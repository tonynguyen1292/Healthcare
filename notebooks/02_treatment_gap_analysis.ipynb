# %% [markdown]
# # Treatment-Gap Analysis — WA Mental Health Treatment Gap
#
# Covers **Epic H2 — Treatment-Gap Metric Computation** and **Epic H3 — Regional & Demographic Comparative Reporting**. Depends on `01_data_ingestion_wa.ipynb` output (`data_processed/wa_treatment_gap_summary.csv`).
#
# **Status: stub only — not started.**

# %% [markdown]
# ## Sprint 2 — Gap computation (H2.1, H2.2, H2.3)

# %%
# H2.1 — National/state-level treatment gap (need % minus service-use %)
# TODO (Sprint 2): implement, source from Table 3-equivalent (12-month disorder) and Table 6-equivalent (consultations)

# %%
# H2.2 — PHN-level treatment gap
# TODO (Sprint 2): implement from modelled 'Any 12-month mental disorder' and 'Use of mental health services' tables

# %%
# H2.3 — Attach uncertainty bounds to every computed gap figure
# RSE/MoE (state-level tables) and RRMSE/CI (PHN-modelled, see methodology sheets)
# Mitigates docs/initiation/02_risk_register.md R-01 — do not report point estimates alone
# TODO (Sprint 2): implement uncertainty propagation

# %% [markdown]
# ## Sprint 3 — Comparative reporting (H3.1, H3.2, H3.3)

# %%
# H3.1 — WA vs national/other-state benchmark table + chart
# TODO (Sprint 3): implement, acceptance criteria in docs/04_business_requirements.md BR-01

# %%
# H3.2 — PHN comparison view, uncertainty-aware
# Do not rank PHNs as confidently different when confidence intervals overlap (R-01)
# TODO (Sprint 3): implement ranking/comparison visualisation

# %%
# H3.3 — Age/sex demographic breakdown where source data allows
# TODO (Sprint 3): implement, acceptance criteria in docs/04_business_requirements.md BR-03
